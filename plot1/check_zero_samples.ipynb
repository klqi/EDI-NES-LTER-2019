# %%
import pandas as pd
import numpy as np

# %%
samples = pd.read_csv("../auto_join/level_1b_manual.csv")
check = samples[samples.Biovolume == 0]

# %%
check.to_csv("zero_feat")
# Out:
#         Unnamed: 0                                    associatedMedia  \
# 5762          5762  http://ifcb-data.whoi.edu/NESLTER_transect/D20...
# 16905        16905  http://ifcb-data.whoi.edu/NESLTER_transect/D20...
# 17161        17161  http://ifcb-data.whoi.edu/NESLTER_transect/D20...
# 18288        18288  http://ifcb-data.whoi.edu/NESLTER_transect/D20...
# 27649        27649  http://ifcb-data.whoi.edu/NESLTER_transect/D20...
# 79470        79470  http://ifcb-data.whoi.edu/NESLTER_transect/D20...
# 130276      162275  http://ifcb-data.whoi.edu/NESLTER_transect/D20...
#
#        data_provider_category_HumanObservation  \
# 5762                                  detritus
# 16905                                      mix
# 17161                                 detritus
# 18288                                 detritus
# 27649                                 detritus
# 79470                                 detritus
# 130276                                detritus
#
# ...
