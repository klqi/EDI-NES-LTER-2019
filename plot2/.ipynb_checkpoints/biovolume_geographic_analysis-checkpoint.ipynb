# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import subprocess

# %%
# Prompt user for manual or automated argument
while (True):
    dataset_type = str(input("Please enter 'manual' or 'automated' for the type of data set you are processing: "))
    # make case insenstive
    dataset_type = dataset_type.lower()
    if (dataset_type == "manual" or dataset_type == "automated"):
        break
    print("Invalid argument")
# Out:
# Please enter 'manual' or 'automated' for the type of data set you are processing: manual

# %%
# first call bash script to get necessary file inputs
# for geographic script, choose query_samples for underway gps data alignment as input script
# for worms script, choose names_ids.csv for input script
# subprocess.call(['./exec.sh'])

# %%
# read different columns based on dataset type
if (dataset_type == 'manual'):
    columns = ['permalink', 'namespace_manual', 'worms_higher_order_manual', 'Biovolume', 'MajorAxisLength']
else:
    columns = ['permalink', 'namespace_automated', 'Biovolume', 'MajorAxisLength']

# %%
# read in level 1_b file
all_rois = pd.read_csv('level_1b.csv', usecols=columns)
all_rois
# Out:
#                                                 permalink  \
# 0       http://ifcb-data.whoi.edu/NESLTER_transect/D20...
# 1       http://ifcb-data.whoi.edu/NESLTER_transect/D20...
# 2       http://ifcb-data.whoi.edu/NESLTER_transect/D20...
# 3       http://ifcb-data.whoi.edu/NESLTER_transect/D20...
# 4       http://ifcb-data.whoi.edu/NESLTER_transect/D20...
# 5       http://ifcb-data.whoi.edu/NESLTER_transect/D20...
# 6       http://ifcb-data.whoi.edu/NESLTER_transect/D20...
# 7       http://ifcb-data.whoi.edu/NESLTER_transect/D20...
# 8       http://ifcb-data.whoi.edu/NESLTER_transect/D20...
# 9       http://ifcb-data.whoi.edu/NESLTER_transect/D20...
# 10      http://ifcb-data.whoi.edu/NESLTER_transect/D20...
# 11      http://ifcb-data.whoi.edu/NESLTER_transect/D20...
# 12      http://ifcb-data.whoi.edu/NESLTER_transect/D20...
# 13      http://ifcb-data.whoi.edu/NESLTER_transect/D20...
# 14      http://ifcb-data.whoi.edu/NESLTER_transect/D20...
# 15      http://ifcb-data.whoi.edu/NESLTER_transect/D20...
# 16      http://ifcb-data.whoi.edu/NESLTER_transect/D20...
# 17      http://ifcb-data.whoi.edu/NESLTER_transect/D20...
# 18      http://ifcb-data.whoi.edu/NESLTER_transect/D20...
# 19      http://ifcb-data.whoi.edu/NESLTER_transect/D20...
# 20      http://ifcb-data.whoi.edu/NESLTER_transect/D20...
# 21      http://ifcb-data.whoi.edu/NESLTER_transect/D20...
# 22      http://ifcb-data.whoi.edu/NESLTER_transect/D20...
# 23      http://ifcb-data.whoi.edu/NESLTER_transect/D20...
# 24      http://ifcb-data.whoi.edu/NESLTER_transect/D20...
# 25      http://ifcb-data.whoi.edu/NESLTER_transect/D20...
# 26      http://ifcb-data.whoi.edu/NESLTER_transect/D20...
# 27      http://ifcb-data.whoi.edu/NESLTER_transect/D20...
# 28      http://ifcb-data.whoi.edu/NESLTER_transect/D20...
# 29      http://ifcb-data.whoi.edu/NESLTER_transect/D20...
# ...                                                   ...
# 165358  http://ifcb-data.whoi.edu/NESLTER_transect/D20...
# 165359  http://ifcb-data.whoi.edu/NESLTER_transect/D20...
# 165360  http://ifcb-data.whoi.edu/NESLTER_transect/D20...
# 165361  http://ifcb-data.whoi.edu/NESLTER_transect/D20...
# 165362  http://ifcb-data.whoi.edu/NESLTER_transect/D20...
# 165363  http://ifcb-data.whoi.edu/NESLTER_transect/D20...
# 165364  http://ifcb-data.whoi.edu/NESLTER_transect/D20...
# 165365  http://ifcb-data.whoi.edu/NESLTER_transect/D20...
# 165366  http://ifcb-data.whoi.edu/NESLTER_transect/D20...
# 165367  http://ifcb-data.whoi.edu/NESLTER_transect/D20...
# 165368  http://ifcb-data.whoi.edu/NESLTER_transect/D20...
# 165369  http://ifcb-data.whoi.edu/NESLTER_transect/D20...
# 165370  http://ifcb-data.whoi.edu/NESLTER_transect/D20...
# 165371  http://ifcb-data.whoi.edu/NESLTER_transect/D20...
# 165372  http://ifcb-data.whoi.edu/NESLTER_transect/D20...
# 165373  http://ifcb-data.whoi.edu/NESLTER_transect/D20...
# 165374  http://ifcb-data.whoi.edu/NESLTER_transect/D20...
# 165375  http://ifcb-data.whoi.edu/NESLTER_transect/D20...
# 165376  http://ifcb-data.whoi.edu/NESLTER_transect/D20...
# 165377  http://ifcb-data.whoi.edu/NESLTER_transect/D20...
# 165378  http://ifcb-data.whoi.edu/NESLTER_transect/D20...
# 165379  http://ifcb-data.whoi.edu/NESLTER_transect/D20...
# 165380  http://ifcb-data.whoi.edu/NESLTER_transect/D20...
# 165381  http://ifcb-data.whoi.edu/NESLTER_transect/D20...
# 165382  http://ifcb-data.whoi.edu/NESLTER_transect/D20...
# 165383  http://ifcb-data.whoi.edu/NESLTER_transect/D20...
# 165384  http://ifcb-data.whoi.edu/NESLTER_transect/D20...
# 165385  http://ifcb-data.whoi.edu/NESLTER_transect/D20...
# 165386  http://ifcb-data.whoi.edu/NESLTER_transect/D20...
# 165387  http://ifcb-data.whoi.edu/NESLTER_transect/D20...
#
#             namespace_manual worms_higher_order_manual     Biovolume  \
# 0                      other                       NaN  2.435732e+04
# 1                   detritus                       NaN  2.591726e+05
# 2                        mix                       NaN  1.897522e+03
# 3                        mix                       NaN  7.636426e+03
# 4               Rhizosolenia         Bacillariophyceae  3.260394e+05
# 5              Cylindrotheca         Bacillariophyceae  6.346017e+02
# 6                        mix                       NaN  1.835194e+03
# 7                        mix                       NaN  1.526814e+03
# 8                   detritus                       NaN  3.818606e+03
# 9                        mix                       NaN  4.228584e+03
# 10                  detritus                       NaN  5.426316e+03
# 11                       mix                       NaN  1.303761e+03
# 12                       mix                       NaN  4.082500e+03
# 13                       mix                       NaN  4.369170e+03
# 14                  detritus                       NaN  6.721516e+04
# 15      Guinardia delicatula         Bacillariophyceae  2.001195e+03
# 16                       mix                       NaN  4.831770e+03
# 17                       mix                       NaN  1.920299e+03
# 18                       mix                       NaN  1.773429e+03
# 19                  detritus                       NaN  6.436069e+05
# 20                       mix                       NaN  1.884170e+03
# 21                       mix                       NaN  1.814619e+03
# 22                       mix                       NaN  7.082721e+03
# 23         Bacillariophyceae         Bacillariophyceae  5.364732e+04
# 24              Rhizosolenia         Bacillariophyceae  1.470041e+06
# 25              Rhizosolenia         Bacillariophyceae  2.412118e+04
# 26                       mix                       NaN  2.474790e+03
# 27                       mix                       NaN  3.083239e+03
# 28                  detritus                       NaN  1.048114e+04
# 29                       mix                       NaN  3.959192e+03
# ...                      ...                       ...           ...
# 165358                   mix                       NaN  9.284192e+03
# 165359         Thalassiosira         Bacillariophyceae  5.793992e+05
# 165360                   mix                       NaN  5.791526e+03
# 165361                   mix                       NaN  7.060729e+03
# 165362                   mix                       NaN  1.193884e+04
# 165363                   mix                       NaN  7.486415e+03
# 165364                   mix                       NaN  3.629325e+03
# 165365                 other                       NaN  6.234412e+04
# 165366                 other                       NaN  1.372719e+04
# 165367                   mix                       NaN  8.092743e+03
# 165368           Chaetoceros         Bacillariophyceae  1.298842e+05
# 165369                 other                       NaN  2.938895e+03
# 165370                 other                       NaN  3.198455e+04
# 165371                   mix                       NaN  2.765387e+03
# 165372              detritus                       NaN  5.678511e+04
# 165373                 other                       NaN  1.343167e+03
# 165374                   mix                       NaN  2.464579e+03
# 165375  Ditylum brightwellii         Bacillariophyceae  4.160562e+05
# 165376                 other                       NaN  3.535766e+04
# 165377                   mix                       NaN  6.196294e+03
# 165378                   mix                       NaN  7.426725e+03
# 165379                   mix                       NaN  6.431626e+03
# 165380                   mix                       NaN  3.746349e+03
# 165381                 other                       NaN  3.341476e+04
# 165382        Leptocylindrus         Bacillariophyceae  2.614891e+03
# 165383  Guinardia delicatula         Bacillariophyceae  9.056093e+05
# 165384        Leptocylindrus         Bacillariophyceae  1.754269e+03
# 165385                   mix                       NaN  4.270210e+03
# 165386                   mix                       NaN  7.739314e+03
# 165387           Chaetoceros         Bacillariophyceae  1.638294e+05
#
#         MajorAxisLength
# 0             77.822688
# 1            202.786943
# 2             27.889806
# 3             25.485570
# 4           1132.735167
# 5             50.928938
# 6             25.001681
# 7             19.599726
# 8             28.950308
# 9             39.014287
# 10            25.348423
# 11            26.707540
# 12            28.486121
# 13            28.103358
# 14            82.161327
# 15            18.237029
# 16            24.504635
# 17            18.403325
# 18            28.261696
# 19           189.119408
# 20            17.497134
# 21            26.853434
# 22            44.314817
# 23           639.796214
# 24          1188.493350
# 25           366.290436
# 26            29.014449
# 27            28.396587
# 28            38.997056
# 29            51.431697
# ...                 ...
# 165358        43.587860
# 165359       105.507312
# 165360        34.699805
# 165361        45.382281
# 165362        36.239206
# 165363        26.001402
# 165364        22.167039
# 165365        62.980535
# 165366        36.799458
# 165367        27.157869
# 165368       225.912681
# 165369        30.248089
# 165370        53.272586
# 165371        24.898425
# 165372        81.782458
# 165373        25.292084
# 165374        27.931706
# 165375       643.998073
# 165376        92.831275
# 165377        38.187884
# 165378        34.589947
# 165379        38.397401
# 165380        24.668808
# 165381        52.486640
# 165382       135.994298
# 165383      1097.507030
# 165384       107.438575
# 165385        32.084733
# 165386        48.224053
# 165387       587.765062
#
# [165388 rows x 5 columns]

# %%
# Prompt user for type of analsyis
while (True):
    analysis_type = str(input("Please enter 'species', 'higher ranks', or 'all' for the type analysis: "))
    # make case insenstive
    analsyis_type = analysis_type.lower()
    if (analysis_type == 'species' or analysis_type == 'higher ranks' or analysis_type == 'all'):
        break
    print("Invalid argument")
# Show drop down list if 'species' is chosen
if (analysis_type == 'species'):
    higher_rank = 'worms_higher_order_{}'.format(dataset_type)
    all_species = set(all_rois.loc[all_rois[higher_rank].notna(), 
                                  'namespace_{}'.format(dataset_type)])
    print(all_species)
# Out:
# Please enter 'species', 'higher ranks', or 'all' for the type analysis: species
# {'Cylindrotheca', 'Pseudo-nitzschia', 'Apedinella', 'Licmophora', 'Thalassiosira', 'Katodinium or Torodinium', 'Phaeocystis', 'Eucampia', 'Chaetoceros', 'cryptophyta', 'Mesodinium', 'Dictyocha', 'Dinophysis', 'Rhizosolenia', 'Ephemera', 'amoeba', 'Guinardia flaccida', 'Stephanopyxis', 'Strombidium oculatum', 'Cerataulina pelagica', 'Guinardia delicatula', 'Dactyliosolen fragilissimus', 'Protoperidinium', 'Proterythropsis sp', 'Pleurosigma', 'Ceratium', 'Coscinodiscus', 'Bacteriastrum', 'Chaetoceros danicus', 'Odontella', 'Leptocylindrus mediterraneus', 'Pyramimonas', 'Ophiaster', 'Euglena', 'Amphidinium', 'Ditylum brightwellii', 'Skeletonema', 'Dinophyceae', 'Corethron hystrix', 'Calciopappus', 'Pleuronema', 'Prorocentrum', 'Guinardia striata', 'Thalassionema', 'Tintinnida', 'Asterionellopsis glacialis', 'Radiozoa', 'Heterocapsa triquetra', 'Emiliania huxleyi', 'Lauderia annulata', 'Corymbellus', 'Bacillariophyceae', 'Chaetoceros debilis', 'Gyrodinium', 'Dactyliosolen blavyanus', 'Stenosemella sp1', 'Laboea strobila', 'Leptocylindrus'}

# %%
# prompt user to ask for desired size distribution, keep at 20 for now
threshold = input('Please enter minimum Major Axis Length to analyze (micrometers): ')
threshold = float(threshold)

# %%
# get higher order data if dataset is automated
if (dataset_type == 'automated'):
    auto_taxon_info = pd.read_csv('resolved_auto.csv', 
                                  usecols=['name', 'resolved_names', 'resolved_higher_order_fromgnr'])
    # merge to get taxa data
    all_rois = pd.merge(all_rois, auto_taxon_info, how='left', left_on='namespace_automated', right_on='name')
    # rename resolved_higher_order column to match
    all_rois.rename(columns={'resolved_higher_order_fromgnr':'worms_higher_order_automated'}, inplace=True)
else:
    man_taxon_info = pd.read_csv('resolved_manual.csv', 
                                  usecols=['name', 'resolved_names'])
    # merge to get taxa data
    samples = pd.merge(all_rois, man_taxon_info, how='left', left_on='namespace_manual', right_on='name')

# %%
# separate out roi id from permalink
all_rois['roi'] = all_rois['permalink']
all_rois.roi = all_rois.roi.str.slice(68, 74)
# gets rid of leading zeros
all_rois.roi = all_rois.roi.str.lstrip("0")
# cut permalink to just be permalink of sample
all_rois.permalink = all_rois.permalink.str.slice(0, 67)

# %%
# read in gps coordinates file
coords = pd.read_csv('comparison.csv', usecols=['pid', 'gps_furuno_latitude'])
# merge with all_rois based on smaple ids
all_rois = pd.merge(all_rois, coords, how='left', left_on='permalink', right_on='pid')

# %%
# calculate total biovolume per sample
total = all_rois.groupby('permalink')['Biovolume'].sum().reset_index()
total.rename(columns={'Biovolume':'total_biovolume'}, inplace=True)
# merge 2 data frames based on sample_identifier
all_rois = pd.merge(all_rois, total, how='left', on='permalink')

# %%
# filter out rows below threshold
all_rois = all_rois[all_rois.MajorAxisLength > threshold]

# %%
# group by sample identifiers and higher ranks to calculate total biovolume per ranking
rois = all_rois.groupby(
    ['permalink', 'worms_higher_order_{}'.format(dataset_type)]).agg(
    {
        'Biovolume': 'sum',
        'gps_furuno_latitude': 'first',
        'total_biovolume': 'first'
    }
).reset_index()
# calculate percent biovolume
rois['percent_biovolume'] = rois['Biovolume']/rois['total_biovolume']

# %%
# take duplicate latitudes and add their concentrations together
fig, ax = plt.subplots(figsize=(15,7))
# use unstack()
rois = rois.groupby(['gps_furuno_latitude','worms_higher_order_{}'.format(dataset_type)]).sum()['percent_biovolume']
rois.unstack().plot(ax=ax)
# add titles and axes labels
plt.xlabel('LTER Stations')
plt.ylabel('% Biovolume in targets with Major Axis Length > {} micrometers'.format(threshold))
plt.title('MVCO Phytoplankton Biovolume ({} classifications)'.format(dataset_type))
plt.grid(True)
# set stations as tick marks
ax.set_xticks([41.1967, 41.03, 40.8633, 40.6967, 40.5133, 40.3633, 40.2267, 40.1367, 40.0983, 39.94, 39.7733])
ax.set_xticklabels(np.arange(1,12))
# set comments
ax.text(41.1967, -0.15, "Coast", size = 15, ha = 'center')
ax.text(39.7733, -0.15, "Offshore", size = 15, ha = 'center')
# invert x axis
ax.invert_xaxis()
plt.show()
