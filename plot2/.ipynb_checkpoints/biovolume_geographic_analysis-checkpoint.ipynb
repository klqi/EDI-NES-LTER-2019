# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import subprocess
import os
from os import path

# %%
# Prompt user for manual or automated argument
while (True):
    dataset_type = str(input("Please enter 'manual' or 'automated' for the type of data set you are processing: "))
    # make case insenstive
    dataset_type = dataset_type.lower()
    if (dataset_type == "manual" or dataset_type == "automated"):
        break
    print("Invalid argument")
# Out:
# Please enter 'manual' or 'automated' for the type of data set you are processing: automated

# %%
# Ask user if running analysis on a new cruise
while (True):
    reply = str(input('Are you running the analysis on a new cruise? (y/n): ')).lower().strip()
    if reply[0] == 'y':
        break
    if reply[0] == 'n':
        break
    else:
        print("Please enter y/n")
# Out:
# Are you running the analysis on a new cruise? (y/n): n

# %%
# first call bash script to get necessary file inputs
# for geographic script, choose query_samples for underway gps data alignment as input script
# for worms script, choose names_ids.csv for input script
# only call if files don't exist or calling on new cruise data so program doesn't need to take full time to run
if ( not reply[0] != 'y' or not (path.exists('resolved_auto.csv') 
        and path.exists('resolved_manual.csv' and path.exists('comparison.csv')))):
    subprocess.call(['./exec.sh', reply[0]])

# %%
# read different columns based on dataset type
if (dataset_type == 'manual'):
    columns = ['permalink', 'namespace_manual', 'worms_higher_order_manual', 'Biovolume', 'MajorAxisLength']
else:
    columns = ['permalink', 'namespace_automated', 'Biovolume', 'MajorAxisLength']

# %%
# read in level 1_b file
all_rois = pd.read_csv('level_1b.csv', usecols=columns)

# %%
'''# Prompt user for type of analsyis
while (True):
    analysis_type = str(input("Please enter 'species', 'higher ranks', or 'all' for the type analysis: "))
    # make case insenstive
    analsyis_type = analysis_type.lower()
    if (analysis_type == 'species' or analysis_type == 'higher ranks' or analysis_type == 'all'):
        break
    print("Invalid argument")
# Show drop down list if 'species' is chosen
if (analysis_type == 'species'):
    higher_rank = 'worms_higher_order_{}'.format(dataset_type)
    all_species = set(all_rois.loc[all_rois[higher_rank].notna(), 
                                  'namespace_{}'.format(dataset_type)])
    print(all_species)'''
# Out:
# '# Prompt user for type of analsyis\nwhile (True):\n    analysis_type = str(input("Please enter \'species\', \'higher ranks\', or \'all\' for the type analysis: "))\n    # make case insenstive\n    analsyis_type = analysis_type.lower()\n    if (analysis_type == \'species\' or analysis_type == \'higher ranks\' or analysis_type == \'all\'):\n        break\n    print("Invalid argument")\n# Show drop down list if \'species\' is chosen\nif (analysis_type == \'species\'):\n    higher_rank = \'worms_higher_order_{}\'.format(dataset_type)\n    all_species = set(all_rois.loc[all_rois[higher_rank].notna(), \n                                  \'namespace_{}\'.format(dataset_type)])\n    print(all_species)'

# %%
# prompt user to ask for desired size distribution, keep at 20 for now
threshold = input('Please enter minimum Major Axis Length to analyze (micrometers): ')
threshold = float(threshold)
# Out:
# Please enter minimum Major Axis Length to analyze (micrometers): 20

# %%
# get higher order data if dataset is automated
if (dataset_type == 'automated'):
    auto_taxon_info = pd.read_csv('resolved_auto.csv', 
                                  usecols=['name', 'resolved_names', 'resolved_higher_order_fromgnr', 'alt_datasource'])
    # merge to get taxa data
    all_rois = pd.merge(all_rois, auto_taxon_info, how='left', left_on='namespace_automated', right_on='name')
    # rename resolved_higher_order column to match
    all_rois.rename(columns={'resolved_higher_order_fromgnr':'worms_higher_order_automated'}, inplace=True)
else:
    man_taxon_info = pd.read_csv('resolved_manual.csv', 
                                  usecols=['name', 'resolved_names', 'alt_datasource'])
    # merge to get taxa data
    all_rois = pd.merge(all_rois, man_taxon_info, how='left', left_on='namespace_manual', right_on='name')

# %%
# separate out roi id from permalink
all_rois['roi'] = all_rois['permalink']
all_rois.roi = all_rois.roi.str.slice(68, 74)
# gets rid of leading zeros
all_rois.roi = all_rois.roi.str.lstrip("0")
# cut permalink to just be permalink of sample
all_rois.permalink = all_rois.permalink.str.slice(0, 67)

# %%
# read in gps coordinates file
coords = pd.read_csv('comparison.csv', usecols=['pid', 'gps_furuno_latitude'])
# merge with all_rois based on smaple ids
all_rois = pd.merge(all_rois, coords, how='left', left_on='permalink', right_on='pid')

# %%
# first exclude abiotic particles
all_rois = all_rois[all_rois['alt_datasource'] != "OCB"]
# calculate total biovolume per sample
total = all_rois.groupby('permalink')['Biovolume'].sum().reset_index()
total.rename(columns={'Biovolume':'total_biovolume'}, inplace=True)
# merge 2 data frames based on sample_identifier
all_rois = pd.merge(all_rois, total, how='left', on='permalink')

# %%
# filter out rows below threshold
all_rois = all_rois[all_rois.MajorAxisLength > threshold]

# %%
# group by sample identifiers and higher ranks to calculate total biovolume per ranking
all_rois = all_rois.groupby(
    ['permalink', 'worms_higher_order_{}'.format(dataset_type)]).agg(
    {
        'Biovolume': 'sum',
        'gps_furuno_latitude': 'first',
        'total_biovolume': 'first'
    }
).reset_index()
# calculate percent biovolume
all_rois['percent_biovolume'] = all_rois['Biovolume']/all_rois['total_biovolume']

# %%
# take duplicate latitudes and add their concentrations together to make percent biovolume plot
fig, ax = plt.subplots(figsize=(15,7))
# use unstack()
rois = all_rois.groupby(['gps_furuno_latitude','worms_higher_order_{}'.format(dataset_type)]).sum()['percent_biovolume']
rois.unstack().plot(ax=ax, marker='o')
# add titles and axes labels
plt.xlabel('LTER Stations Latitudes')
plt.ylabel('% Biovolume in targets with Major Axis Length > {} micrometers '.format(threshold))
plt.title('Percent Biovolume along Transect({} classifications)'.format(dataset_type))
plt.grid(True)
# set stations as tick marks
ax.set_xticks([41.1967, 41.03, 40.8633, 40.6967, 40.5133, 40.3633, 40.2267, 40.1367, 40.0983, 39.94, 39.7733])
# ax.set_xticklabels(np.arange(1,12))
# set comments
ax.text(41.1967, -0.15, "Coast", size = 15, ha = 'center')
ax.text(39.7733, -0.15, "Offshore", size = 15, ha = 'center')
# invert x axis
ax.invert_xaxis()
plt.show()

# %%
all_rois
# Out:
#                                              permalink  \
# 0    http://ifcb-data.whoi.edu/NESLTER_transect/D20...
# 1    http://ifcb-data.whoi.edu/NESLTER_transect/D20...
# 2    http://ifcb-data.whoi.edu/NESLTER_transect/D20...
# 3    http://ifcb-data.whoi.edu/NESLTER_transect/D20...
# 4    http://ifcb-data.whoi.edu/NESLTER_transect/D20...
# 5    http://ifcb-data.whoi.edu/NESLTER_transect/D20...
# 6    http://ifcb-data.whoi.edu/NESLTER_transect/D20...
# 7    http://ifcb-data.whoi.edu/NESLTER_transect/D20...
# 8    http://ifcb-data.whoi.edu/NESLTER_transect/D20...
# 9    http://ifcb-data.whoi.edu/NESLTER_transect/D20...
# 10   http://ifcb-data.whoi.edu/NESLTER_transect/D20...
# 11   http://ifcb-data.whoi.edu/NESLTER_transect/D20...
# 12   http://ifcb-data.whoi.edu/NESLTER_transect/D20...
# 13   http://ifcb-data.whoi.edu/NESLTER_transect/D20...
# 14   http://ifcb-data.whoi.edu/NESLTER_transect/D20...
# 15   http://ifcb-data.whoi.edu/NESLTER_transect/D20...
# 16   http://ifcb-data.whoi.edu/NESLTER_transect/D20...
# 17   http://ifcb-data.whoi.edu/NESLTER_transect/D20...
# 18   http://ifcb-data.whoi.edu/NESLTER_transect/D20...
# 19   http://ifcb-data.whoi.edu/NESLTER_transect/D20...
# 20   http://ifcb-data.whoi.edu/NESLTER_transect/D20...
# 21   http://ifcb-data.whoi.edu/NESLTER_transect/D20...
# 22   http://ifcb-data.whoi.edu/NESLTER_transect/D20...
# 23   http://ifcb-data.whoi.edu/NESLTER_transect/D20...
# 24   http://ifcb-data.whoi.edu/NESLTER_transect/D20...
# 25   http://ifcb-data.whoi.edu/NESLTER_transect/D20...
# 26   http://ifcb-data.whoi.edu/NESLTER_transect/D20...
# 27   http://ifcb-data.whoi.edu/NESLTER_transect/D20...
# 28   http://ifcb-data.whoi.edu/NESLTER_transect/D20...
# 29   http://ifcb-data.whoi.edu/NESLTER_transect/D20...
# ..                                                 ...
# 249  http://ifcb-data.whoi.edu/NESLTER_transect/D20...
# 250  http://ifcb-data.whoi.edu/NESLTER_transect/D20...
# 251  http://ifcb-data.whoi.edu/NESLTER_transect/D20...
# 252  http://ifcb-data.whoi.edu/NESLTER_transect/D20...
# 253  http://ifcb-data.whoi.edu/NESLTER_transect/D20...
# 254  http://ifcb-data.whoi.edu/NESLTER_transect/D20...
# 255  http://ifcb-data.whoi.edu/NESLTER_transect/D20...
# 256  http://ifcb-data.whoi.edu/NESLTER_transect/D20...
# 257  http://ifcb-data.whoi.edu/NESLTER_transect/D20...
# 258  http://ifcb-data.whoi.edu/NESLTER_transect/D20...
# 259  http://ifcb-data.whoi.edu/NESLTER_transect/D20...
# 260  http://ifcb-data.whoi.edu/NESLTER_transect/D20...
# 261  http://ifcb-data.whoi.edu/NESLTER_transect/D20...
# 262  http://ifcb-data.whoi.edu/NESLTER_transect/D20...
# 263  http://ifcb-data.whoi.edu/NESLTER_transect/D20...
# 264  http://ifcb-data.whoi.edu/NESLTER_transect/D20...
# 265  http://ifcb-data.whoi.edu/NESLTER_transect/D20...
# 266  http://ifcb-data.whoi.edu/NESLTER_transect/D20...
# 267  http://ifcb-data.whoi.edu/NESLTER_transect/D20...
# 268  http://ifcb-data.whoi.edu/NESLTER_transect/D20...
# 269  http://ifcb-data.whoi.edu/NESLTER_transect/D20...
# 270  http://ifcb-data.whoi.edu/NESLTER_transect/D20...
# 271  http://ifcb-data.whoi.edu/NESLTER_transect/D20...
# 272  http://ifcb-data.whoi.edu/NESLTER_transect/D20...
# 273  http://ifcb-data.whoi.edu/NESLTER_transect/D20...
# 274  http://ifcb-data.whoi.edu/NESLTER_transect/D20...
# 275  http://ifcb-data.whoi.edu/NESLTER_transect/D20...
# 276  http://ifcb-data.whoi.edu/NESLTER_transect/D20...
#
# 7                40.8155     6.040722e+07           0.165846
# 8                40.7681     6.984536e+07           0.733067
# 9                40.7681     6.984536e+07           0.036198
# 10               40.7681     6.984536e+07           0.005069
# 11               40.7681     6.984536e+07           0.184916
# 12               40.7175     6.049530e+07           0.763848
# 13               40.7175     6.049530e+07           0.041484
# 14               40.7175     6.049530e+07           0.001266
# 15               40.7175     6.049530e+07           0.136911
# 16               40.6987     5.162485e+07           0.730087
# 17               40.6987     5.162485e+07           0.043631
# 18               40.6987     5.162485e+07           0.001699
# 19               40.6987     5.162485e+07           0.179818
# 20               40.6923     6.453388e+07           0.662059
# 21               40.6923     6.453388e+07           0.135862
# 22               40.6923     6.453388e+07           0.002672
# 23               40.6923     6.453388e+07           0.163216
# 24               40.6871     6.597826e+07           0.743736
# 25               40.6871     6.597826e+07           0.059569
# 26               40.6871     6.597826e+07           0.000817
# 27               40.6871     6.597826e+07           0.146770
# 28               40.6784     5.412540e+07           0.658654
# 29               40.6784     5.412540e+07           0.083924
# ..                   ...              ...                ...
# 249              40.8595     4.711723e+07           0.004261
# 250              40.8595     4.711723e+07           0.216301
# 251              40.8517     5.131580e+07           0.700136
# 252              40.8517     5.131580e+07           0.071438
# 253              40.8517     5.131580e+07           0.004689
# 254              40.8517     5.131580e+07           0.186359
# 255              40.8759     5.929540e+07           0.734532
# 256              40.8759     5.929540e+07           0.073512
# 257              40.8759     5.929540e+07           0.001604
# 258              40.8759     5.929540e+07           0.158318
# 259              40.9322     5.978377e+07           0.728906
# 260              40.9322     5.978377e+07           0.041784
# 261              40.9322     5.978377e+07           0.003358
# 262              40.9322     5.978377e+07           0.172674
# 263              40.9698     9.543781e+07           0.794481
# 264              40.9698     9.543781e+07           0.045789
# 265              40.9698     9.543781e+07           0.000985
# 266              40.9698     9.543781e+07           0.122896
# 267              40.9953     8.596253e+07           0.774878
# 268              40.9953     8.596253e+07           0.090556
# 269              40.9953     8.596253e+07           0.000837
# 270              40.9953     8.596253e+07           0.106496
# 271              41.0178     9.488133e+07           0.824842
# 272              41.0178     9.488133e+07           0.024127
# 273              41.0178     9.488133e+07           0.001889
# 274              41.0178     9.488133e+07           0.120223
# 275              41.0359     2.336300e+07           0.898624
# 276              41.0359     2.336300e+07           0.004576
# 277              41.0359     2.336300e+07           0.001593
# 278              41.0359     2.336300e+07           0.077460
#
# [279 rows x 6 columns]

# %%
# take duplicate latitudes and add their concentrations together
fig, ax = plt.subplots(figsize=(15,7))
# use unstack()
rois = all_rois.groupby(['gps_furuno_latitude','worms_higher_order_{}'.format(dataset_type)]).sum()['Biovolume']
rois.unstack().plot(ax=ax, marker='o')
# add titles and axes labels
plt.xlabel('LTER Stations Latitudes')
plt.ylabel('% Biovolume in targets with Major Axis Length > {} micrometers'.format(threshold))
plt.title('Percent Biovolume along Transect({} classifications)'.format(dataset_type))
plt.grid(True)
# set stations as tick marks
ax.set_xticks([41.1967, 41.03, 40.8633, 40.6967, 40.5133, 40.3633, 40.2267, 40.1367, 40.0983, 39.94, 39.7733])
# ax.set_xticklabels(np.arange(1,12))
# set comments
ax.text(41.1967, -0.15, "Coast", size = 15, ha = 'center')
ax.text(39.7733, -0.15, "Offshore", size = 15, ha = 'center')
# invert x axis
ax.invert_xaxis()
plt.show()
